# %% [markdown]
# ## Analysis of solar intensity
# Advanced Lab

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.stats import norm

# %%
# load data file
data_file = pd.read_excel('AM1_5.xls')
# data_file = pd.read_excel('ASTMG173.xls')
N_students = 15
# data_file

# %%
length_data = len(data_file)
data_file
# Out:
#       Wavelength (nm)  Extraterrestrial W*m-2*nm-1  Global tilt  W*m-2*nm-1  \
# 0               280.0                      0.08200             4.730900e-23
# 1               280.5                      0.09900             1.230700e-21
# 2               281.0                      0.15000             5.689500e-21
# 3               281.5                      0.21200             1.566200e-19
# 4               282.0                      0.26700             1.194600e-18
# 5               282.5                      0.30300             4.543600e-18
# 6               283.0                      0.32500             1.845200e-17
# 7               283.5                      0.32300             3.536000e-17
# 8               284.0                      0.29900             7.267000e-16
# 9               284.5                      0.25024             2.485600e-15
# 10              285.0                      0.17589             8.014200e-15
# ...

# %%
# data_file['Unnamed: 1'][1:length_data]

# %%
lambda_nm = data_file['Wavelength (nm)'][1:length_data]

I_extr = data_file['Extraterrestrial W*m-2*nm-1'][1:length_data]
# I_glob_tilt = data_file['Global tilt W*m-2*nm-1'][1:length_data]
I_dir_circum = data_file['Direct+circumsolar W*m-2*nm-1'][1:length_data]
plt.plot(lambda_nm,I_extr)
plt.plot(lambda_nm,I_dir_circum)
# plt.xlabel('exam score (of 100 pts)')
# plt.ylabel('Frequency')
# plt.title(r'Exam 1 scores histogram $\barx=%.2f$, $\sigma=%.2f$'%(mean1,std1))
# plt.xlim([0,110])
# plt.grid(True)
plt.show()

# %%
np.sum(I_extr)
# Out:
# 1356.068289999998

# %%
np.sum(I_dir_circum)
# Out:
# 887.6479061606396
